# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = plt.imread('Virat1.jpg')
plt.imshow(image)
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
face = face_cascade.detectMultiScale(image)
face
# Out:
# array([[43, 37, 98, 98]])

# %%
(x, y, w, h) = face[0]
x, y, w, h
# Out:
# (43, 37, 98, 98)

# %%
writable_image = image.copy()

# %%
face_image = cv2.rectangle(writable_image, (x, y), (x + w, y + h), (255, 0, 0), 2)
plt.imshow(face_image)

# %%
plt.imshow(writable_image)
plt.show()

# %% [markdown]
# ### The reason both face_image and writable_image have the bounding box is that cv2.rectangle() modifies the writable_image in place. When you draw the rectangle on writable_image, the face_image variable is just a reference to the same writable_image. Thus, both face_image and writable_image point to the same image data with the bounding box already drawn on it.

# %%
plt.imshow(image)
plt.show()

# %%
image2 = image.copy()

# %%
# Detect faces
faces = face_cascade.detectMultiScale(image2, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw rectangles around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image2, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Display the output
plt.imshow(image2)
plt.show()

# %% [markdown]
# ## Check

# %%
image_1 = plt.imread('Virat2.jpg')
image_1
# Out:
# array([[[217, 212, 206],
#         [218, 213, 207],
#         [219, 214, 208],
#         ...,
#         [141, 126,  95],
#         [143, 128,  97],
#         [144, 129,  98]],
#
#        [[217, 212, 206],
#         [218, 213, 207],
#         [219, 214, 208],
#         ...,
#         [141, 126,  95],
#         [143, 128,  97],
#         [144, 129,  98]],
#
#        [[217, 212, 206],
#         [218, 213, 207],
#         [219, 214, 208],
#         ...,
#         [140, 125,  94],
#         [142, 127,  96],
#         [143, 128,  97]],
#
#        ...,
#
#        [[ 33,  36,  53],
#         [ 32,  35,  50],
#         [ 32,  35,  50],
#         ...,
#         [110, 102,  89],
#         [105,  99,  87],
#         [103,  99,  88]],
#
#        [[ 32,  35,  52],
#         [ 32,  35,  50],
#         [ 32,  35,  50],
#         ...,
#         [113, 106,  90],
#         [104,  98,  86],
#         [102,  95,  85]],
#
#        [[ 30,  33,  50],
#         [ 31,  34,  49],
#         [ 32,  35,  50],
# ...

# %%
image_2 = cv2.imread('Virat2.jpg')
image_2
# Out:
# array([[[206, 212, 217],
#         [207, 213, 218],
#         [208, 214, 219],
#         ...,
#         [ 95, 126, 141],
#         [ 97, 128, 143],
#         [ 98, 129, 144]],
#
#        [[206, 212, 217],
#         [207, 213, 218],
#         [208, 214, 219],
#         ...,
#         [ 95, 126, 141],
#         [ 97, 128, 143],
#         [ 98, 129, 144]],
#
#        [[206, 212, 217],
#         [207, 213, 218],
#         [208, 214, 219],
#         ...,
#         [ 94, 125, 140],
#         [ 96, 127, 142],
#         [ 97, 128, 143]],
#
#        ...,
#
#        [[ 53,  36,  33],
#         [ 50,  35,  32],
#         [ 50,  35,  32],
#         ...,
#         [ 89, 102, 110],
#         [ 87,  99, 105],
#         [ 88,  99, 103]],
#
#        [[ 52,  35,  32],
#         [ 50,  35,  32],
#         [ 50,  35,  32],
#         ...,
#         [ 90, 106, 113],
#         [ 86,  98, 104],
#         [ 85,  95, 102]],
#
#        [[ 50,  33,  30],
#         [ 49,  34,  31],
#         [ 50,  35,  32],
# ...

# %% [markdown]
# ## Image-->Grayscale-->Face Detection

# %%
image = plt.imread('Virat1.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')
plt.show()

# %%
image = plt.imread('Virat1.jpg')

plt.imshow(image, cmap='gray')
plt.show()

# %%
image = plt.imread('Virat1.jpg')

gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Detect faces
faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw rectangles around the detected faces
for (x, y, w, h) in faces:
    cv2.rectangle(gray_image, (x, y), (x + w, y + h), (255, 0, 0), 2)
    
# Display the output
plt.imshow(gray_image, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image using OpenCV (BGR format)
image = cv2.imread('Virat1.jpg')

# Convert the image to grayscale
# Convert to grayscale (face detection works better on grayscale images)
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Load the face cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Detect faces
faces = face_cascade.detectMultiScale(image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Draw rectangles around the detected faces on the BGR image
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 2)

# Convert BGR image back to RGB for display
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the output
plt.imshow(rgb_image)
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.imshow(image)
plt.show()
